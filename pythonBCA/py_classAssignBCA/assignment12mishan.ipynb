# %%
import tkinter as tk
from tkinter import ttk
from tkinter import *
import smtplib
from tkinter import filedialog
import re

# this is a function which returns the selected combo box item
root = Tk()
root.geometry('800x450')
root.configure()
root.title('Lab Python 1841030')

# This is the section of code which creates the main window
root.geometry('1045x761')
root.configure()
root.title('XML Parse')

def file_opener():
   input = filedialog.askopenfile(initialdir="/")
   print(input)
   for i in input:
      print(i)
        
# Button label
x = Button(root, text ='Select a .txt file to open', command = lambda:file_opener())
x.pack()

Label(root, text="XML Title:").place(x=50, y=20)

Namet = Entry(root,  width=35)
Namet.place(x=115, y=20)

def display():
    x = "XML Title : " + root.attrib['shelf']
    name = Label(window, text=x, font=("Helvetica", 12),width = 50, background="black",borderwidth = 2, relief="solid", highlightbackground="blue")
    name.place(x = 220,y=80)
    frame = Frame(window,width=700,height=300,borderwidth=1)
    frame.place(x=40,y=150)
    row = ['Movie Name','Year','IMDB Rating','Description']
    for i in range(0,1):
        for j in range(0, 4):
            e = Entry(frame, width=15,font=('Arial',10,'bold'),bg = 'purple',fg = 'white')
            e.grid(row=i, column=j)
            if(j==3):
                e.configure(width=65)
            e.insert(END,row[j])

    for i in range(0,len(items)):
        row.clear()
        row.append(items[i].attributes['title'].value)
        row.append(root[i][2].text)
        row.append(root[i][4].text)
        row.append(root[i][5].text)
        for j in range(0, 4):
            e = Entry(frame, width=15,font=('Arial',10,'bold'),bg = 'white',fg = 'purple')
            e.grid(row=i+1, column=j)
            if(j==3):
                e.configure(width=65)
            e.insert(END,row[j])
            #e.config(state = DISABLED)


root.mainloop()
# Out:
# <_io.TextIOWrapper name='C:/Users/Mishan RG/Desktop/data.xml' mode='r' encoding='cp1252'>
# <College>
#
#     <Student>
#
#         <id>030</id>
#
#         <name>Mishan</name>
#
#         <program>BCA</program>
#
#         <grade>D</grade>
#
#     </Student>
#
#
#
#     <Student>
#
#         <id>075</id>
#
#         <name>John</name>
#
#         <program>BBA</program>
#
#         <grade>D</grade>
#
#     </Student>
#
#
#
#     <Student>
#
#         <id>085</id>
#
#         <name>Jane</name>
#
#         <program>BDS</program>
#
#         <grade>D</grade>
#
#     </Student>
#
#
#
#     <Student>
#
#         <id>126</id>
#
#         <name>Jack</name>
#
#         <program>MBBS</program>
#
#         <grade>D</grade>
#
#     </Student>
#
# <Student><id>182</id><name>Mishan</name><program>BBA</program><grade>D</grade></Student><Employee><ID>767</ID><Full Name>Mishan regmi</Full Name><Salary>1544</Salary><Year of Experience>7</Year of Experience></Employee></College>

# %%
import tkinter as tk
from tkinter import ttk
from tkinter import *
import smtplib
from tkinter import filedialog
import re

# this is a function which returns the selected combo box item
root = Tk()
root.geometry('800x450')
root.configure()
root.title('Lab Python 1841030')

# This is the section of code which creates the main window
root.geometry('1045x761')
root.configure()
root.title('XML Parse')

def file_opener():
   input = filedialog.askopenfile(initialdir="/")
   print(input)
   for i in input:
      print(i)
        
# Button label
x = Button(root, text ='Select a .txt file to open', command = lambda:file_opener())
x.pack()

Label(root, text="XML Title:").place(x=50, y=20)

Namet = Entry(root,  width=35)
Namet.place(x=115, y=20)

class Table: 
      
    def __init__(self,root): 
          
        # code for creating table 
        for i in range(total_rows): 
            for j in range(total_columns): 
                  
                self.e = Entry(root, width=20, fg='blue', 
                               font=('Arial',16,'bold')) 
                  
                self.e.grid(row=i, column=j) 
                self.e.insert(END, lst[i][j]) 

root.mainloop()
